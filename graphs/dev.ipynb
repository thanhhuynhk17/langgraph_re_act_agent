# %%
# # Get orders for customer "customer123", fastapi at localhost:8000
# HTTP GET /api/customers/customer123/orders

response = client.call_method(
    server_key="graph_rag",
    method_name="get_orders",
    parameters={"customer_id": "customer123"}
)
# Out:
# multi_dish_lookup
# menu_value_count_and_price
# take_order
# [None, None, None]
